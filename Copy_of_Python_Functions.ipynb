# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Functions
#
# Piece of code which  is already created and can be called when required.
#
# 1) Built in Function - print(),input(),int(),float(),isgit(),isalpha(),isalphnum()
#
# 2) User Defined Function - Created by Pogrammer to organize their code and to user reusability.
#
# Two things are very important
#
# DEFINING A FUNCTION  - def  functionaname()
#
# CALL A FUNCTION   functionname()

# %%
def area(a):
  return a*a


area(3)

# %% [markdown]
# #**Function without arguments or return value**

# %%
#Write a program to calculate area of a square using a user defined function
#

def square():
  x=int(input("Enter the side of a square:"))
  area=x*x
  print("Area of a square is",area)


print("We are solving area of square today")
square()
# Out:
# We are solving area of square today
# Enter the side of a square:6
# Area of a square is 36

# %% [markdown]
# #Global Variable /Local Variable

# %%
area=0  #global
def square():
  x=int(input("Enter the side of a square:"))
  area=x*x  # x is still a Local variables
  print("Area of a square is",area)


print("We are solving area of square today")
square()

# %% [markdown]
# #**Function with the arguments**

# %%
def square(y):
  area=y*y
  print("Area of a square is",area)


print("We are solving area of square today")
print()
x=int(input("Enter the side of a square:"))
square(x)
# Out:
# We are solving area of square today
#
# Enter the side of a square:7
# Area of a square is 49

# %% [markdown]
# #**Function with argument and return value**

# %%
def square(y):
  area=y*y   #local scope
  return area     # scope of area variable is only limited to square function because it is defined inside it


print("We are solving area of square today")
print()
x=int(input("Enter the side of a square:"))
result=square(x)
print(result)
print("Area of a square is",square(x))

# result=square()
# print("Area of square is",result)
# Out:
# We are solving area of square today
#
# Enter the side of a square:6
# 36
# Area of a square is 36

# %% [markdown]
# #**function with default argument and return value**

# %%
def square(y=9):
  area=y*y
  return area     # scopr of area variable is only limited to square function because it is defined inside it


print("We are solving area of square today")
print(square())
x=int(input("Enter the side of a square:"))

result = square(x)
print("Area of a square is",result)
# result=square()  #since we are not passing any argument, default value in the definitation of a function will be used.
# print("Area of a square is",result)
# Out:
# We are solving area of square today
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3604106817.py in <cell line: 0>()
#       5
#       6 print("We are solving area of square today")
# ----> 7 print(square())
#       8 x=int(input("Enter the side of a square:"))
#       9
#
# TypeError: square() missing 1 required positional argument: 'y'

# %%
#Create a function to print a welcome message for a user. Example  def message():
#Then call this function

def message():
  print("Welcome to python!")


message()
# Out:
# Welcome to python!

# %%
#Write a Python function calculate_area that takes two arguments: length and width, and returns the area of a rectangle.

def calculate_area(length, width):
  area=length*width
  return area


length=int(input("enter the width of your rectangle: "))
width=int(input("enter the width of you rectangle: "))

result=calculate_area(length, width)
print(result)
# Out:
# enter the width of your rectangle: 7
# enter the width of you rectangle: 6
# 42

# %%
#Create a function greet that accepts two arguments: name and greeting, where greeting has a default value of "Hello".
#The function should return a greeting message.

def greet(name, greeting="Hello"):
  message=greeting+" "+name+"!"
  return message


name=input("enter your name: ")
greeting=input("enter a greeting: ")

print(greet(name, greeting))
print(greet(name))
# Out:
# enter your name: Avery
# enter a greeting: Welcome
# Welcome Avery!
# Hello Avery!

# %%
#Write a function calculate_discount that takes two arguments — price and discount_percentage (default is 10%). The function should return the discounted price

def calculate_discount(price, discount_percentage=10):
  total=price-price*discount_percentage/100
  return total

price=int(input("enter the price: "))
discount_percentage=int(input("enter the discount %: "))

print(calculate_discount(price, discount_percentage))
print(calculate_discount(price))
# Out:
# enter the price: 100
# enter the discount %: 5
# 95.0
# 90.0

# %% [markdown]
# #**Function with multiple return values**

# %%
#Write a program to calculate both area and perimeter of a square

def square(side):
  area=side*side
  perimeter=4*side
  return area,perimeter

print(square(5))

a,p=square(6.5)
print("Area is", a,"Perimeter is ",p)
# Out:
# (25, 20)
# Area is 42.25 Perimeter is  26.0

# %%
def areaofS(a):
  area=a*a
  perimeter=4*a
  return area, perimeter


a,p=areaofS(4)
print("area",a, "Peri",p)
print(areaofS(5))
print("Hello")
# Out:
# area 16 Peri 16
# (25, 20)
# Hello

# %% [markdown]
# #Positional arguments and keyword arguments
#
# positional argument follows keyword argument

# %%
def funn(a,b,c):
  print(a,b,c)

a=int(input("Enter a number:"))
b=int(input("Enter a number:"))

funn(a,b,c=a)
# Out:
# Enter a number:4
# Enter a number:5
# 4 5 4

# %%
# Write a function shipping_cost that accepts the following value in argument:

# weight (in kg)
# location (default = "local")

# If location is "local", cost = weight * 5
# If "international", cost = weight * 15
# Return the cost.

def shipping_cost(weight, location="l"):
  if location=="l":
    cost=weight*5
  else:
    cost=weight*15
  TotalCost = cost
  return TotalCost

weight=int(input(" How much does your package weigh(kg)? "))

location=input("Where is the final location? local/international: Enter (L/ I) ")

print(shipping_cost(weight,location.lower()))
print(shipping_cost(weight))
# Out:
#  How much does your package weigh(kg)? 6
# Where is the final location? local/international: Enter (L/ I)
# 90
# 30

# %%
# Write a function book_ticket with arguments:

# name
# destination
# ticket_type (default: "Economy")
# meal (default: "Vegetarian")

# Return a string summarizing the booking.Example: Hello <name>, your destination is <destination>. Your ticket type is <ticket_type> and you have selected meal as <meal>
