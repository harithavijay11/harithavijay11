# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_DF_practiceTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Employee_ID": [101,102,103,104,105,106,107,108,109,110],
    "Name": ["John","Mary","Sam","Lisa","David","Emma","Mike","Sara","Alex","Nina"],
    "Department": ["IT","HR","Finance","IT","Marketing","Finance","IT","HR","Marketing","IT"],
    "Age": [28,35,42,25,31,45,29,38,27,33],
    "Salary": [70000,85000,95000,65000,72000,105000,78000,88000,69000,91000],
    "Experience": [3,8,15,2,6,18,4,10,3,7],
    "City": ["Toronto","Vancouver","Calgary","Toronto","Montreal","Calgary","Ottawa","Toronto","Vancouver","Montreal"],
    "Performance": [4.2,4.8,4.5,3.9,4.1,4.9,4.0,4.6,3.8,4.7],
    "Projects": [5,8,12,3,6,15,4,10,2,9],
    "Remote": ["Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes"]
}

df = pd.DataFrame(data)

df
# Out:
#    Employee_ID   Name Department  Age  Salary  Experience       City  \
# 0          101   John         IT   28   70000           3    Toronto
# 1          102   Mary         HR   35   85000           8  Vancouver
# 2          103    Sam    Finance   42   95000          15    Calgary
# 3          104   Lisa         IT   25   65000           2    Toronto
# 4          105  David  Marketing   31   72000           6   Montreal
# 5          106   Emma    Finance   45  105000          18    Calgary
# 6          107   Mike         IT   29   78000           4     Ottawa
# 7          108   Sara         HR   38   88000          10    Toronto
# 8          109   Alex  Marketing   27   69000           3  Vancouver
# 9          110   Nina         IT   33   91000           7   Montreal
#
#    Performance  Projects Remote
# 0          4.2         5    Yes
# 1          4.8         8     No
# 2          4.5        12    Yes
# 3          3.9         3    Yes
# 4          4.1         6     No
# ...

# %%
#Select Name column

#Select Name and Salary columns

#Display all column names not values

# %%
#Name and Department for rows 0 to 5

# %%
#Get the row where Employee_ID is 105

# %%
#Get the row where Employee_ID is 105 ( do you want to set employee id as index first)

# %%
#Get employees with Employee_ID 102, 106, and 110

#Get rows from Employee_ID 103 to 107

# %%
#Find all employees whose salary is greater than 80000

# %%
#Find employees working in the IT department

#Find employees who are from Toronto

#Find employees who work remotely

# %%
#Find IT employees with salary greater than 75000

# %%
#Find employees with more than 5 years experience and performance rating above 4.5

# %%
#Find employees from Toronto OR Vancouver

# %% [markdown]
# #Challenging Qs

# %%
#Using .loc, get Name and Salary of employees earning more than 90000

# %%
#Using .loc, increase salary by 5000 for employees in IT

# %%
#Find the average salary of employees in Finance

#Find the employee with the highest salary

#Sort employees by Salary from highest to lowest
