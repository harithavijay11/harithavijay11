# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_FileHandling_PythonNotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **File Handling**
#
#
# Advantages of File Handling:
#
# Permanent Data Storage: File handling allows us to save data permanently on a storage device. Even after closing the program, the information remains available for future use.
#
# Data Sharing and Management: Files make it easier to store, retrieve, update, and share information between different programs or users.
#
# The key function for working with files in Python is the open() function.
#
# The open() function takes two parameters; filename, and mode.
#
# There are four different methods (modes) for opening a file:
#
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exists

# %%
L=[]

for i in range(1,6):
  data=input("Enter your name:")
  L.append(data)

print(L)
# Out:
# Enter your name:Geetu
# Enter your name:Pritesh
# Enter your name:Hetvi
# Enter your name:Kelsey
# Enter your name:Muntasir
# ['Geetu', 'Pritesh', 'Hetvi', 'Kelsey', 'Muntasir']

# %% [markdown]
# #**Opening file**
#
# -- open()
#
# -- read() - Reads the entire file as a single string.

# %%
f=open("datatry.txt")
# data=f.read()
# print(data)

print(f.read())
# Out:
# My name is Geetu.
# I work in Npower Canada
# I am teaching Python.
# Its a good sunny day today.

# %%
f=open("TestData.txt","r")
data=f.read()
print(data)
f.close()
# Out:
# Lily found a tiny injured bird in her backyard and carefully nursed it back to health.
# Every morning, she would sing to it, and the bird would chirp back happily.
# One day, the bird flew away, leaving Lily a little sad but proud. Weeks later, as she sat in the garden, the same bird returned with a small flower in its beak.
# It was as if the bird was saying, "Thank you, my friend."

# %% [markdown]
# **read(n) Reads first N characters from the file.**

# %%
f=open("datatry.txt","r")
data2=f.read(10)
print(data2)
f.close()
# Out:
# My name is

# %% [markdown]
# **readline() – Reads one line at a time.**

# %%
f=open("datatry.txt","r")
print(f.readline())
# Out:
# My name is Geetu.

# %%
print(f.readline())
# Out:
# Its a good sunny day today.

# %% [markdown]
# **readlines()-Reads all lines and returns a list of strings.**

# %%
f=open("datatry.txt","r")
L=f.readlines()
print(L)
print(len(L))

for i in range(0,len(L)):
    if 'sunny' in L[i]:
      print("Found at", i+1, "line" )



for i in L:
  print(i)


# for i in range(0,len(L)):
#     print(L[i])
# Out:
# ['My name is Geetu.\n', 'I work in Npower Canada\n', 'I am teaching Python.\n', 'Its a good sunny day today.']
# 4
# Found at 4 line
# My name is Geetu.
#
# I work in Npower Canada
#
# I am teaching Python.
#
# Its a good sunny day today.

# %% [markdown]
# #Try this

# %%
#Create a text file ( call it Example.txt) which contains atleast 4 lines.
#Open that file using the file function
#Print the content of the file on the screen using the read()
#Print only first 10 characters of a file
#Print one line at a time from a file

# %% [markdown]
# read(), read(5), readline(), readlines()
#
# 1.   List item
# 2.   List item

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1724/907070862.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
file_path = "/content/drive/MyDrive/FinalAssignmentNic.txt"

# %%
f=open(file_path)
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2618187985.py in <cell line: 0>()
# ----> 1 f=open(file_path)
#       2 print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/FinalAssignmentNic.txt'

# %% [markdown]
# **Creating a file with write()**

# %%
f=open("Example.txt",'w')
data="Hello! How are you doing today?\nI will see you again."
f.write(data)
f.close()

# %%
f=open("Example.txt","r")
data= f.read()
print(data)
# Out:
# Hello! How are you doing today?
# I will see you again.

# %% [markdown]
# **write() – Writes a string to a file (overwrites existing content).**

# %%
f=open("Example.txt",'a')
data="\nI will talk to you later."
f.write(data)
# Out:
# 26

# %% [markdown]
# **writelines() – Writes a list of strings to a file.**
#
# "a" mode appends content instead of overwriting

# %%
f=open("Example2.txt",'a')
L=["Hello\n","How are you?\n","okay! bye"]
f.writelines(L)
f.close()

# %%
f=open("Example2.txt","r")
data= f.read()
print(data)
# Out:
# New Information

# %%
f=open("Example.txt","a")
f.write("Hello\n bye bye")
# Out:
# 14

# %%
f=open("Example2.txt","x")  #file will be opened if it does not exist and it will open in write mode
f.write("New Information")
# Out:
# 15

# %%
f=open("Example3.txt","r")
print(f.read())
# Out:
# New Information

# %% [markdown]
# **Checking if File Exists (Using os module):**

# %%
import os

if os.path.exists("Example3.txt"):
    print("File exists!")
else:
  print("doesnt exist")
# Out:
# doesnt exist

# %%
#String() - split()
f=open("Example2.txt",'a')
f.write("\nIts a gloomy day today.")
f.close()

# %%
f=open("Example2.txt",'r')
print(f.read())
data=f.read()
# Out:
# Hello
# How are you?
# okay! bye
# Its a gloomy day today.

# %%
f=open("Example3.txt","w")
while True:
  name=input("Enter your name:")
  phone=input("Enter your phone:")
  f.write(f"{name}:{phone}\n")

  ch=input("Cotninue? y/n:")
  if ch.lower()=='y':
    continue
  else:
    break

f=open("Example3.txt","r")
data=f.read()
print(data)
# Out:
# Enter your name:Geetu
# Enter your phone:878327687823
# Cotninue? y/n:y
# Enter your name:John
# Enter your phone:7823987723
# Cotninue? y/n:y
# Enter your name:Nancy
# Enter your phone:92379233223
# Cotninue? y/n:n
# Geetu:878327687823
# John:7823987723
# Nancy:92379233223

# %% [markdown]
# **with open()**

# %%
# open an already existing file into an append mode and add two new lines into the file.
# Once done, read the file and count the number of lines in the file.
# If number of lines are greater than 5 , then print only first two lines


with open("Example.txt","a") as f:
    f.write("\n Go Go ")

# %%
f=open("Example.txt",'r')
print(f.read())
# Out:
# Hello! How are you doing today?
# I will see you again.
# I will talk to you later.
#  Go Go

# %% [markdown]
# #Make use of the information we are retrieving from the file

# %%
#Count the number of lines:
f=open("Example2.txt",'r')
# data=f.readlines()
# print("Number of line in my file", len(data))
print(len(f.readlines()))
# Out:
# 1

# %%
#Count the number of words in my file
f=open("Example3.txt",'r')
data=f.readlines()
print(data)
print(len(data))
#L=data.split()  #applying this string function on a string
#print(L)
#print("Number of words in my file are", len(L))
# Out:
# ['Geetu:878327687823\n', 'John:7823987723\n', 'Nancy:92379233223\n']
# 3

# %%
#Count the number of words in a file  - split()  - strings  ( len(), lower(), upper(), title(),startswith(),endswith())

f=open("Example3.txt")
data2=f.read()
words=data2.split(" ")
print(words)
f.close()
# Out:
# ['Geetu:878327687823\nJohn:7823987723\nNancy:92379233223\n']

# %%
import re

with open("Example3.txt", "r") as f:
    text = f.read()

text=text.strip()
parts = re.split(r'[:\n]+', text)
print(len(parts))
# Out:
# 6

# %%
#Read the file Example.txt and count the number of words in a file.
#Also find out if the word today exist in the file or not

f=open("Example.txt")
data=f.read()
if 'today' in data:
  print("Found")



f.close()

# %%
for i in words:


print(L)
# Out:
# [6, 3, 3, 3, 5, 6, 1, 4, 3, 3, 7, 4, 4, 2, 3, 14, 3, 9, 8, 3, 3, 4, 5, 3]

# %%
with open ("Example.txt",'r') as f:
  data=f.read()
  print(data)
# Out:
# Hello! How are you doing today?
# I will see you again.I will talk to you later.
# I will talk to you later.Hello
# How are you?
# okay! bye

# %%
with open("Example.txt","r") as f:   #you do not have to close() your file explicitly
  data=f.read()
  print(data)
# Out:
# Hello! How are you doing today?
# I will see you again.I will talk to you later.HelloHow are you?okay! byeHello
# How are you?
# okay! bye

# %%
# Read data from the input file
with open("Test2.txt", "r") as file:
    lines = file.readlines()  #readlines into the list

print(lines)
# Out:
# ['Nancy 14\n', 'Jasmine 16\n', 'Tammy 18\n', 'Joe  20']

# %%
#convert into dicitionary

D={}
for i in lines:
  name,age=i.split()
  D[name]=age

print(D)



# for i in lines:
#       name,age=i.split()    #split() function works on string
#       D[name]=age

# print(D)



# # Initialize an empty dictionary to store names and ages
# people_data = {}

# # Parse the data and populate the dictionary
# for line in lines:
#     name = line.strip().split()
#     print(name)
    #people_data[name] = int(age)

# # Find the person with the highest age
# max_age_person = max(people_data, key=people_data.get)
# max_age = people_data[max_age_person]

# # Calculate the average age
# average_age = sum(people_data.values()) / len(people_data)

# # Print the results
# print(f"Person with the highest age: {max_age_person}, Age: {max_age}")
# print(f"Average age of all people: {average_age}")

# Write the summary to a new file
# with open("people_summary.txt", "w") as summary_file:
#     for name, age in people_data.items():
#         summary_file.write(f"Name: {name}, Age: {age}\n")

# print("Summary has been written to 'people_summary.txt'.")
# Out:
# {'Nancy': '14', 'Jasmine': '16', 'Tammy': '18', 'Joe': '20'}

# %%
x=max(D.values())


for i in D:
 if x==D[i]:
  print(i)
# Out:
# Joe

# %%
with open("Test.txt",'w') as f:
  for i in D:
    name=i
    phone=D[i]
    data=name+"\t"+phone+"\n"
    f.write(data)

# %%
with open("Test.txt",'r') as f:
  print(f.read())
# Out:
# John	12
# Nancy	14
# Steve	13
# Rohan	10
# Jasmine	11

# %%
#Create a text file with name and scores of 5 students and save that file as student.txt on your computer
#upload that file onto google colab
#Read that file into the list
#convert that file into dicitonary
#Find the name of a student with the highest marks

# %%
data={}

for i in range(0,5):
  name=input("enter your name:")
  phone=input("Enter phone")
  data[name]=phone


print(data)
# Out:
# enter your name:Geetu
# Enter phone92397329234
# enter your name:Johny
# Enter phone43554343
# enter your name:Jasmine
# Enter phone324434
# enter your name:Nancy
# Enter phone234432
# enter your name:Arti
# Enter phone3245
# {'Geetu': '92397329234', 'Johny': '43554343', 'Jasmine': '324434', 'Nancy': '234432', 'Arti': '3245'}

# %%
D={'Geetu':100,"Nancy":200,"Johny":300}
print(D['Geetu'])
# Out:
# 100

# %%
D={1:56,2:67,3:87,10:68}

print(D[10])
# Out:
# 68

# %% [markdown]
# **Login**

# %%
def sign_up():
    new_name = input("Enter a new username: ")
    new_password = input("Enter a new password: ")

    with open("Credentials.txt", "a") as file:
        file.write(f"{new_name},{new_password}\n")

    print("Account created successfully!")

def login():
    name = input("Enter your username: ")
    password = input("Enter your password: ")

    with open("Credentials.txt", "r") as file:
        credentials = file.readlines()

    for cred in credentials:
        stored_name, stored_password = cred.strip().split(",")
        if name == stored_name:
            if password == stored_password:
                print(f"Welcome {name}!")
                return
            else:
                print("Wrong name or password.")
                return

    print("Your name doesn't exist, please create an account.")

# Create Credentials.txt file with initial data
with open("Credentials.txt", "w") as file:
    file.write("Sarah,12ssr\nLisa,pass\nDonna,D00N\n")

# Test the program
while True:
    choice = input("Do you want to sign up or log in? (sign_up/login/exit): ")
    if choice.lower() == "sign_up":
        sign_up()
    elif choice.lower() == "login":
        login()
    elif choice.lower() == "exit":
        break
    else:
        print("Invalid choice. Please enter 'sign_up', 'login', or 'exit'.")
