# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_Sstring_Class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str1 = "HELLO WORLD"
print(str1)
# Out:
# HELLO WORLD

# %%
mystr = 'Hello World' # Define string using single quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = "Hello World" # Define string using double quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = '''Hello
 World
 jhgfgsd''' # Define string using triple quotes  - Multiline string
print(mystr)
# Out:
# Hello
#  World
#  jhgfgsd

# %%
mystr = """Hello
 World""" # Define string using triple quotes
print(mystr)
# Out:
# Hello
#  World

# %%
mystr="Hello. My name is Geetu.\
I teach Python"
print(mystr)  #Creating multiline string without triple quotes .. using \
# Out:
# Hello. My name is Geetu.I teach Python

# %%
x="5"
y=8
print(x*y)
# Out:
# 55555555

# %%
mystr2 = 'Woohoo '
mystr2 = mystr2*5
print(mystr2)   # This operation creates a new string by repeating the original string 5 times.
# Out:
# Woohoo Woohoo Woohoo Woohoo Woohoo

# %%
print(len(mystr2))
#Print length of a string
# Out:
# 35

# %% [markdown]
# #**String Indexing**
#
#
# ![image.png](data:image/png;base64,...)

# %%
strdata="Hello World!"
print(strdata[0]) #First character
print(strdata[-1]) #Last Character
print(strdata[6]) #7th character
# Out:
# H
# !
# W

# %% [markdown]
# #**String Slicing**

# %%
# # #String Slicing
# print(strdata)
# print(strdata[:]) #all the characters of a string
# print(strdata[0:5]) #All the characters from first till 4th -0,1,2,3,4
# print(strdata[0:7:2]) #Every alternate character between 0-7
print(strdata[-1:-5:-1]) #Last four characters
print(strdata[-4:])
print(strdata[5:])
print(strdata[-1:]) #Only last character beacuse negative jump is not provided
print(strdata[::]) #The entire string
print(strdata[2::2]) #Every second character from a string ( jump is 2 , last is not given )
print(strdata[-1:-4])  #It will not print anything because by default jump is considered +1
print(strdata[-1:-4:-1]) #It will print character -1,-2,-3
print(strdata[::-1]) #Reverse the string
print(strdata[-5:-1])# Print the characters -4,-3,-2,-1
print(strdata[:6]) # Retreive first six characters of the string
# Out:
# !dlr
# rld!
#  World!
# !
# Hello World!
# loWrd
#
# !dl
# !dlroW olleH
# orld
# Hello

# %% [markdown]
# #**Update & Delete String**

# %%
#Strings are immutable which means elements of a string cannot be changed once th
strdata[0:5] = 'HOLAA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_486/3355721553.py in <cell line: 0>()
#       1 #Strings are immutable which means elements of a string cannot be changed once th
# ----> 2 strdata[0:5] = 'HOLAA'
#
# TypeError: 'str' object does not support item assignment

# %%
str1="hello"
del str1 # Delete a string
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-672391745.py in <cell line: 0>()
#       1 str1="hello"
#       2 del str1 # Delete a string
# ----> 3 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# #**String Concatenation**

# %%
# String concatenation
s1 = "Come"
s2 = "Again"
s3 = s1 + s2
print(s3)
# Out:
# ComeAgain

# %% [markdown]
# #**Iterating through String**

# %%
# Iteration
mystr1="Hello World"
for i in mystr1:
 print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# #**String Functions**

# %%
str2=" Python Programming "
str2=str2.strip(str2)
print(len(str2))
print(len(str2.strip())) # Removes white space from begining & end
# Out:
# 0
# 0

# %%
print(str2.rstrip()) # Removes all whitespaces at the end of the string
# Out:
#  Python Programming

# %%
print(str2.lstrip()) # Removes all whitespaces at the begining of the string)
# Out:
# Python Programming

# %%
print(str2.lower())
# Out:
#  python programming

# %%
print(str2.upper())
# Out:
#  PYTHON PROGRAMMING

# %%
print(str2.title())
# Out:
#  Python Programming

# %%
str2="Python Programming"
print(str2.replace("mm" , "Ho")) #Replace substring "He" with "Ho"
# Out:
# Python PrograHoing

# %%
print(str2.count("on")) # Number of times substring "one" occurred in string)
# Out:
# 1

# %%
str2="Python Programming"
print(str2.startswith("Python ")) # Return boolean value True if string starts with "one
# Out:
# True

# %%
print(str2.endswith("ing")) # Return boolean value True if string ends with "three"
# Out:
# True

# %%
print(str2.split())
# Out:
# ['Python', 'Programming']

# %%
str4 = "one two three four five six seven"
loc = str4.find("five") # Find the location of word 'five' in the string "str4"
print(loc)
# Out:
# 19

# %%
mystr6 = '123456789'
print(mystr6.isalpha()) # returns True if all the characters in the text are lett
print(mystr6.isalnum()) # returns True if a string contains only letters or numb
print(mystr6.isdecimal()) # returns True if all the characters are decimals (0-9)
print(mystr6.isnumeric()) # returns True if all the characters are numeric (0-9)
# Out:
# False
# True
# True
# True

# %%
mystr6 = 'abcde'
print(mystr6.isalpha()) # returns True if all the characters in the text are lett
print(mystr6.isalnum()) # returns True if a string contains only letters or numb
print(mystr6.isdecimal()) # returns True if all the characters are decimals (0-9)
print(mystr6.isnumeric()) # returns True if all the characters are numeric (0-9)
# Out:
# True
# True
# False
# False

# %%
mystr6 = 'abc12309'
print(mystr6.isalpha()) # returns True if all the characters in the text are lett
print(mystr6.isalnum()) # returns True if a string contains only letters or numb
print(mystr6.isdecimal()) # returns True if all the characters are decimals (0-9)
print(mystr6.isnumeric()) # returns True if all the characters are numeric (0-9)
# Out:
# False
# True
# False
# False

# %%
mystr7 = 'ABCDEF'
print(mystr7.isupper()) # Returns True if all the characters are in upper case
print(mystr7.islower())
# Out:
# True
# False

# %% [markdown]
# #In operator

# %%
data="Hello World"
answer="Wo" in data
print(answer)
# Out:
# True

# %% [markdown]
# #**END**
