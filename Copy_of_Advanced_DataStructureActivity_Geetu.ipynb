# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_Advanced_DataStructureActivity_Geetu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Activity 1: Build Your Own Customer Database
#
# 1. Create an empty list
# 2. Build dictionaries dynamically
# 3. Store multiple dictionaries inside a list
#
# **Step 1: Understand the Data Structure**
#
# If you have ONE customer, how would you store it?
#
# customer = {
#     "name":"Alice",
#     "country":"Canada",
#     "subscription":"Premium",
#     "hours":25
# }
#
# **This is one dictionary.**
#
# **What if Netflix has 1000 customers?**
#
# One dictionary isn't enough.We need something that can hold MANY dictionaries.
# That's where a list comes in.
#
# customers = [ {customer1},{customer2},{customer3},{customer4}
#
# The list stores many customers.Each customer is stored as a dictionary.

# %% [markdown]
# #List of Dicitionary

# %%
L=[]
while True:
  D={}
  Cname=input("Enter name:")
  D['name']=Cname
  CCountry=input("Enter Country:")
  D['country']=CCountry
  CSub=input("Enter Subscription:")
  D['Sub']=CSub
  hours=int(input("Enter hours:"))
  D['hours']=hours
  print("First Dicitionary of Customer created", D)
  L.append(D)  #append individual dicitionary to global List

  ch=input("Add more? y/n:")
  if ch.lower()=='n':
    break

print("The whole database of customers in the list",L)
# Out:
# Enter name:Rohit
# Enter Country:Canada
# Enter SubscriptionPremimum
# Enter hours20
# {'name': 'Rohit', 'country': 'Canada', 'Sub': 'Premimum', 'hours': 20}
# Add more? y/n:y
# Enter name:Jasmine
# Enter Country:Canada
# Enter SubscriptionGold
# Enter hours34
# {'name': 'Jasmine', 'country': 'Canada', 'Sub': 'Gold', 'hours': 34}
# Add more? y/n:n
# [{'name': 'Rohit', 'country': 'Canada', 'Sub': 'Premimum', 'hours': 20}, {'name': 'Jasmine', 'country': 'Canada', 'Sub': 'Gold', 'hours': 34}]

# %% [markdown]
# #Activity 2: Create a Menu driven Program to perform following operations
#
# **Netflix Customer Analytics System — Objectives (What needs to be achieved)**
#
# Add Customer → Dynamically create a customer dictionary and store it inside a list of customers. (Done)
#
# View All Customers → Use a loop to display every customer record stored in the list.
#
# Find Heavy Watchers → Analyze customer data and identify customers who watched more than 20 hours.
#
# Find Top Viewer → Compare watch hours of all customers and find the customer with maximum viewing hours.
#
# Calculate Average Watch Hours → Calculate the average viewing time across all customers.
#
# Subscription Report → Count how many customers belong to each subscription category using a dictionary.
#
# Upgrade Subscription → Search for a customer and update their subscription level (Basic → Standard → Premium).
#
# Search Customer by Country → Filter customer records based on a given country.
#
# Exit Program → Use a while loop and break statement to continuously run the application until the user chooses to exit.

# %%
L=[]

def addcustomer():
  while True:
  D={}
  Cname=input("Enter name:")
  D['name']=Cname
  CCountry=input("Enter Country:")
  D['country']=CCountry
  CSub=input("Enter Subscription:")
  D['Sub']=CSub
  hours=int(input("Enter hours:"))
  D['hours']=hours
  print("First Dicitionary of Customer created", D)
  L.append(D)  #append individual dicitionary to global List

  ch=input("Add more? y/n:")
  if ch.lower()=='n':
    break


def viewcustomer()




while True:

    print("\n==============================")
    print(" Netflix Analytics Dashboard ")
    print("==============================")
    print()
    print("1. Add Customer")
    print("2. View All Customers")
    print("3. Find Heavy Watchers")
    print("4. Find Top Viewer")
    print("5. Calculate Average Watch Hours")
    print("6. Subscription Report")
    print("7. Upgrade Subscription")
    print("8. Search Customer by Country")
    print("9. Show Unique Countries and Genres")
    print("10. Exit")
    print()
    ch=input("Enter your choice:")
    if ch=="1":
      add_customer()
    elif ch=="2":





    elif ch=="10":
      break
    else:
      print("Invalid choice")
# Out:
# ...
#  Netflix Analytics Dashboard
# ...
#
# 1. Add Customer
# 2. View All Customers
# 3. Find Heavy Watchers
# 4. Find Top Viewer
# 5. Calculate Average Watch Hours
# 6. Subscription Report
# 7. Upgrade Subscription
# 8. Search Customer by Country
# 9. Show Unique Countries and Genres
# 10. Exit
#
# Enter your choice:10

# %% [markdown]
# #Solution

# %%
# Netflix Customer Analytics System

customers = []


# 1. Add Customer
def add_customer():
    name = input("Enter customer name: ")
    country = input("Enter country: ")
    subscription = input("Enter subscription (Basic/Standard/Premium): ")
    watch_hours = int(input("Enter watch hours: "))

    customer = {
        "name": name,
        "country": country,
        "subscription": subscription,
        "watch_hours": watch_hours
    }

    customers.append(customer)

    print("Customer added successfully!")


# 2. View All Customers
def view_customers():

    if len(customers) == 0:
        print("No customers available.")
        return

    print("\n--- Customer Records ---")

    for customer in customers:
        print(customer)



# 3. Find Heavy Watchers
def heavy_watchers():

    print("\n--- Heavy Watchers (>20 hours) ---")

    found = False

    for customer in customers:

        if customer["watch_hours"] > 20:
            print(customer["name"], "-", customer["watch_hours"], "hours")
            found = True

    if found == False:
        print("No heavy watchers found.")



# 4. Find Top Viewer
def top_viewer():

    if len(customers) == 0:
        print("No customers available.")
        return

    top_customer = customers[0]

    for customer in customers:

        if customer["watch_hours"] > top_customer["watch_hours"]:
            top_customer = customer


    print("\n--- Top Viewer ---")
    print(top_customer)



# 5. Calculate Average Watch Hours
def average_watch_hours():

    if len(customers) == 0:
        print("No data available.")
        return


    total_hours = 0

    for customer in customers:
        total_hours += customer["watch_hours"]


    average = total_hours / len(customers)

    print("Average Watch Hours:", average)



# 6. Subscription Report
def subscription_report():

    report = {}

    for customer in customers:

        subscription = customer["subscription"]

        if subscription in report:
            report[subscription] += 1

        else:
            report[subscription] = 1


    print("\n--- Subscription Report ---")

    print(report)



# 7. Upgrade Subscription
def upgrade_subscription():

    name = input("Enter customer name to upgrade: ")


    for customer in customers:

        if customer["name"].lower() == name.lower():

            current = customer["subscription"]


            if current == "Basic":
                customer["subscription"] = "Standard"

            elif current == "Standard":
                customer["subscription"] = "Premium"

            else:
                print("Already Premium subscription.")
                return


            print("Subscription upgraded!")
            print(customer)

            return


    print("Customer not found.")



# 8. Search Customer by Country
def search_by_country():

    country = input("Enter country: ")

    found = False


    print("\n--- Customers from", country, "---")


    for customer in customers:

        if customer["country"].lower() == country.lower():

            print(customer)
            found = True


    if found == False:
        print("No customers found.")



# ---------------- MAIN MENU ----------------


while True:

    print("\n====== Netflix Customer Analytics ======")

    print("1. Add Customer")
    print("2. View All Customers")
    print("3. Find Heavy Watchers")
    print("4. Find Top Viewer")
    print("5. Calculate Average Watch Hours")
    print("6. Subscription Report")
    print("7. Upgrade Subscription")
    print("8. Search Customer by Country")
    print("9. Exit")


    choice = input("Enter your choice: ")



    if choice == "1":
        add_customer()

    elif choice == "2":
        view_customers()

    elif choice == "3":
        heavy_watchers()

    elif choice == "4":
        top_viewer()

    elif choice == "5":
        average_watch_hours()

    elif choice == "6":
        subscription_report()

    elif choice == "7":
        upgrade_subscription()

    elif choice == "8":
        search_by_country()

    elif choice == "9":
        print("Exiting Netflix System...")
        break

    else:
        print("Invalid choice. Try again.")
# Out:
# ====== Netflix Customer Analytics ======
# 1. Add Customer
# 2. View All Customers
# 3. Find Heavy Watchers
# 4. Find Top Viewer
# 5. Calculate Average Watch Hours
# 6. Subscription Report
# 7. Upgrade Subscription
# 8. Search Customer by Country
# 9. Exit
# Enter your choice: 1
# Enter customer name: Geetu
# Enter country: Canada
# Enter subscription (Basic/Standard/Premium): Premium
# Enter watch hours: 45
# Customer added successfully!
#
# ====== Netflix Customer Analytics ======
# 1. Add Customer
# 2. View All Customers
# 3. Find Heavy Watchers
# 4. Find Top Viewer
# 5. Calculate Average Watch Hours
# 6. Subscription Report
# 7. Upgrade Subscription
# 8. Search Customer by Country
# 9. Exit
# Enter your choice: 2
#
# --- Customer Records ---
# {'name': 'Geetu', 'country': 'Canada', 'subscription': 'Premium', 'watch_hours': 45}
#
# ====== Netflix Customer Analytics ======
# 1. Add Customer
# 2. View All Customers
# 3. Find Heavy Watchers
# 4. Find Top Viewer
# ...

# %% [markdown]
# #File Handling
#
# A text file stores information as plain text, so Python needs to convert the text into a data structure before we can analyze it. We read lines, split values, create dictionaries, and store them in a list. When data changes, we write the updated list back into the file

# %% [markdown]
# #Advanced Activity: Netflix Customer Analytics System with File Handling
#
# Modify the existing Netflix Customer Analytics System by adding file handling so that customer data is permanently stored and available even after the program is closed.
#
#
# Currently, your program stores customer records inside a list. The problem is that once the program terminates, all customer data is lost.
#
# Your task is to enhance the application by implementing file handling using a text file (customers.txt).
