# %% [markdown]
# <a href="https://colab.research.google.com/github/harithavijay11/harithavijay11/blob/main/Copy_of_Class3_conditional_statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python Conditional Statements Tutorial**
#
# Conditional statements allow Python to make decisions and execute different blocks of code based on specific conditions. They include:
#
# --if statement
#
# --if-else statement
#
# --if-elif-else statement
#
# --Nested conditional statements

# %% [markdown]
# #**Example**

# %%
age=int(input("enter your age:"))  #important to convert string value to integer
if age>=18:
   print("Eligible to vote")   # indentation
else:
  print("Not eligible to vote")
# Out:
# enter your age:56
# Eligible to vote

# %%
age=int(input("Enter your age:"))
if age>=18:
   print("You can vote")
else:
   print("You cant vote")
   print("hello")
# Out:
# Enter your age:45
# You can vote
# hello

# %%
age=16
if age>=18:
  print("Eligible to vote")
  print("you can also drive")
print("Bye bye")
# Out:
# Bye bye

# %%
#Take an input of an age from a user and print whether they are eligible to vote or not.

age = int(input("Enter your age:"))
if age >= 18:
  print("Eligible to vote")
else:
  print("Not Eligible to vote")

# %% [markdown]
# #**Practice Questions**
#
# Take an input of a number from a user and print whether its a positive number
# or negative number.
#
#
#
# ---
#
#
# Take input of two numbers and print the larget is two numbers on the screen.
#
#
# ---
#
#
#
# Take an input of a character and print whether it s a vowel or a consonant.
#
#
# ---
#
#
# Take an input of total score and an age of a person . If age > 18 and score is above 80, they are eligible for scholarship otherwsie they do not get the scholarship.
#
#
# ---
#
#
#
# Take input of scores in three subjects. Calculate average score.If average score is>= 90, print "Excellent"

# %% [markdown]
# #**Relational & Logical Operators**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Logical Operators:  AND, OR , NOT
#Take an input of total score and an age of a person . If age > 18 and score is above 80, they are eligible for scholarship otherwsie they do not get the scholarship.
# Print appropate message after taking inputs.

age=int(input("Enter your age:"))
score=int(input("Enter your score:"))

if not(age>18 and score>80):
  print("Your are eligible ")
else:
  print("Not eligible ")
# Out:
# Enter your age:19
# Enter your score:89
# Not eligible

# %%
#Same question with OR operator

age=int(input("Enter your age:"))
score=int(input("Enter your score:"))
x=6
y=4

if (age>18 or score>80) and (x>5 or y<3) :
  print("Your are eligible ")
else:
  print("Not eligible ")
# Out:
# Enter your age:16
# Enter your score:34
# Not eligible

# %%
x=5
y=5
if not(x==y):
  print("Equal")
else:
  print("Not Equal")
# Out:
# Not Equal

# %%
#Take input of a character .if it is a vowel. Print "Vowel" else print "Consonant"

ch=input("Enter one character:")
ch=ch.lower()

if ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u':

  print("vowel")
else:
  print("Consonant")
# Out:
# Enter one character:A
# vowel

# %% [markdown]
# #**if-elif-else Statement**
#
# Use this when you have multiple conditions to check.

# %%
#Evaluate Grade based on Average score.
#If Total score> 80: Grade A ,
#Total score 60-80, Grade B ,
# 40-60, Grade C,
#less than 40: Grade F

score=int(input("Enter total score:"))
if score>=80:
  print("Grade A")
elif score>=60 and score<80:
  print("Grade B")
elif score>=40 and score<60:
  print("Grade C")
else:
  print("Grade F")
# Out:
# Enter total score:56
# Grade C

# %%
#Other way of solving the same question

score = int(input("Enter total score: "))

if score >= 80:
    print("Grade A")
elif score >= 60:
    print("Grade B")
elif score >= 40:
    print("Grade C")
else:
    print("Grade F")
# Out:
# Enter total score: 56
# Grade C

# %%
#Using logical grouping to solv ethe same question

score = int(input("Enter total score: "))

if score >= 80:
    grade = "Grade A"
elif 60 <= score < 80:
    grade = "Grade B"
elif 40 <= score < 60:
    grade = "Grade C"
else:
    grade = "Grade F"

print(grade)
# Out:
# Enter total score: 78
# Grade B

# %%
x=4
y=5

if x<5:
  print("hello")
if x>2 and y<7:
  print("Bye")
if x>5:
  print("okay")
# Out:
# hello

# %%
createpass=input("enter your password:")
#Password should be atleast 8 digit long
#Password should have both capital letter and small letters
#Password should have numeric digit.

if len(createpass)<8:
  print("Password should be atleast 8 digit long")

if createpass.islower()!=True and createpass.isupper()!=True:
  print("Password should have both capital letter and small letters")

if (createpass.isnumeric())!=True:
  print("Password should have numeric digit.")
# Out:
# enter your password:ABCD456
# Password should be atleast 8 digit long
# Password should have numeric digit.

# %%
cpass=input("Enter pass:")
print("Password is created")
checkpass=input("Enter password to login:")
if cpass==checkpass:
  print("Login ")
else:
  print("You can not login")
# Out:
# Enter pass:geetusodhi
# Password is created
#  Enter password to login:Gers
# You can not login

# %%
#Check whether a number is an even number or not

num=int(input("Enter a number:"))
if num%2==0:
  print("Even")
else:
  print("odd")
# Out:
# Enter a number:45
# odd

# %%
# Check if a year is a leap year

year = 2024
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2024 is a leap year.

# %%
#Find the largest number among three numbers

a, b, c = 10, 20, 15
if a > b and a > c:
    print(f"{a} is the largest.")
elif b > c:
    print(f"{b} is the largest.")
else:
    print(f"{c} is the largest.")
# Out:
# 20 is the largest.

# %% [markdown]
# #**Nested if Statements Example**
#
# In a nested if statement, you place one if statement inside another if statement to check for multiple conditions. Here's an example that checks if a person is eligible for a driver's license based on their age and whether they have passed a driving test.
#
# Problem: Check if a person is eligible for a driver's license based on age and driving test result.
#
#
# **Conditions:**
#
# The person must be at least 18 years old.
#
# If they are between 18 and 25 years old, they must  passed g2 driving test.
# If they are older than 25, they can automatically eligible for  G  driver's license without passing the test.

# %%
age = int(input("Enter your age: "))

if age >= 18 and age <= 25:  # Nested if for people between 18 and 25
        has_passed_test = input("Have you passed the driving test? (yes/no): ").lower()
        if has_passed_test == "yes":
            print("You are eligible for a driver's license!")
        else:
            print("You must pass the driving test to be eligible.")
elif age>25:
        print("You are eligible for a driver's license!")
else:
    print("You are not eligible for a driver's license yet.")
# Out:
# Enter your age: 30
# You are eligible for a driver's license!

# %%
age=int(input("Enter your age:"))

if age>=18:
  print("You are an adult")
elif age>=13 and age<18:
  print("You are a teenager")
elif age>=3 and age<=12:
  print("you are a child")
elif age >1 and age<3:
  print("You are a toddler")
elif age>0 and age<=1:
  print("You are an infant")
else:
  print("Invalid ")
# Out:
# Enter your age:15
# You are a teenager

# %% [markdown]
# #**Common Mistakes**
# Forgetting to indent properly.
#
# Using = instead of == for comparison.
#
# Missing the colon (:) at the end of conditional statements.
#
# Not covering all possible cases in if-elif-else.

# %% [markdown]
# #**Practice Question**

# %%
#Take input of total amount from the user.
#IF total amount > 5000, print you get 50% discount
#If total amount is between 2000-5000, print you get 25% discount
#If total amount is between 1000-2000, print you get 10% disocunt
#else no discount

# %% [markdown]
# #**More Pracitce Questions**
#
# #Bank Loan Eligibility
# Problem: Write a program that checks if a person is eligible for a bank loan based on their credit score and income. The conditions for loan approval could be:
#
# Credit score >= 700
#
# Income >= $50,000 per year
#
# Challenge: Include additional conditions for different loan types (e.g., home loans vs personal loans) with different thresholds.
#
# #Restaurant Order Menu
# Problem: Create a program for a restaurant where the user selects from a menu of food items. Based on their selection, the program should calculate the total price. Each item has a price, and there is a discount based on the total amount spent:
#
# If the total is above $50, apply a 10% discount.
#
# If the total is above $100, apply a 15% discount.
#
# #Shipping Cost Calculator
#
# Problem: Write a program that calculates the shipping cost based on the weight of the package. The shipping costs are:
#
# Up to 5kg: $5
#
# Between 5kg and 10kg: $10
#
# Above 10kg: $20
#
# Challenge: Implement the program to check if the customer is a premium member and provide a 20% discount for them.
#
#
# #Number Guessing Game
# Problem: Create a simple number guessing game where the program randomly selects a number between 1 and 100. The user has 5 attempts to guess the number, and the program should provide hints:
#
# If the guess is too high, the program says "Too high!"
#
# If the guess is too low, the program says "Too low!"
#
# If the guess is correct, the program says "Correct!"
#
# Challenge: Allow the user to play multiple rounds and track how many times they guessed correctly.
#
#
# #ATM Machine
# Problem: Write a program that simulates an ATM machine. The user should be able to:
#
# Enter their PIN.
#
# If the PIN is correct, they are allowed to check their balance, withdraw money, or deposit money.
#
# If the PIN is incorrect, display an error message.
#
# The program should also handle:
#
# Invalid inputs (non-numeric PIN, non-numeric amount for withdrawal/deposit).
# Ensure the withdrawal amount doesn’t exceed the balance.

# %% [markdown]
# #**END**
